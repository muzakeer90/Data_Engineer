# %% [markdown]
# # Section 1: Lambda Expressions

# %% [markdown]
# **Question 1**```pythonnumber = 8```Write a lambda expression to calculate the square of `number`.

# %%
number = 8
square = lambda n: n ** 2
print(square(number))

# %% [markdown]
# **Question 2**```pythonnumber = 5```Write a lambda expression to calculate the cube of `number`.

# %%
number = 5
cube = lambda n: n ** 3
print(cube(number))

# %% [markdown]
# **Question 3**```pythona = 25b = 17```Write a lambda expression to add `a` and `b`.

# %%
a = 25
b = 17
add = lambda a, b: a + b
print(add(a, b))

# %% [markdown]
# **Question 4**```pythona = 50b = 18```Write a lambda expression to subtract `b` from `a`.

# %%
a = 50
b = 18
subtract = lambda a, b: a - b
print(subtract(a, b))

# %% [markdown]
# **Question 5**```pythona = 12b = 9```Write a lambda expression to multiply `a` and `b`.

# %%
a = 12
b = 9
multiply = lambda a, b: a * b
print(multiply(a, b))

# %% [markdown]
# **Question 6**```pythona = 100b = 4```Write a lambda expression to divide `a` by `b`.

# %%
a = 100
b = 4
divide = lambda a, b: a / b
print(divide(a, b))

# %% [markdown]
# **Question 7**```pythona = 72b = 91```Write a lambda expression to return the larger number.

# %%
a = 72
b = 91
larger = lambda a, b: a if a > b else b
print(larger(a, b))

# %% [markdown]
# **Question 8**```pythona = 46b = 28```Write a lambda expression to return the smaller number.

# %%
a = 46
b = 28
smaller = lambda a, b: a if a < b else b
print(smaller(a, b))

# %% [markdown]
# **Question 9**```pythonnumber = 34```Write a lambda expression that returns `True` when the number is even and `False` otherwise.

# %%
number = 34
is_even = lambda n: n % 2 == 0
print(is_even(number))

# %% [markdown]
# **Question 10**```pythonnumber = 27```Write a lambda expression that returns `True` when the number is odd and `False` otherwise.

# %%
number = 27
is_odd = lambda n: n % 2 != 0
print(is_odd(number))

# %% [markdown]
# **Question 11**```pythonlength = 12width = 8```Write a lambda expression to calculate the area of a rectangle.

# %%
length = 12
width = 8
area = lambda l, w: l * w
print(area(length, width))

# %% [markdown]
# **Question 12**```pythonradius = 7```Write a lambda expression to calculate the area of a circle using `3.14`.

# %%
radius = 7
area = lambda r: 3.14 * r * r
print(area(radius))

# %% [markdown]
# **Question 13**```pythonlength = 15width = 10```Write a lambda expression to calculate the perimeter of a rectangle.

# %%
length = 15
width = 10
perimeter = lambda l, w: 2 * (l + w)
print(perimeter(length, width))

# %% [markdown]
# **Question 14**```pythoncelsius = 35```Write a lambda expression to convert Celsius into Fahrenheit.

# %%
celsius = 35
to_fahrenheit = lambda c: (c * 9 / 5) + 32
print(to_fahrenheit(celsius))

# %% [markdown]
# **Question 15**```pythonfahrenheit = 104```Write a lambda expression to convert Fahrenheit into Celsius.

# %%
fahrenheit = 104
to_celsius = lambda f: (f - 32) * 5 / 9
print(to_celsius(fahrenheit))

# %% [markdown]
# **Question 16**```pythonword = "Python"```Write a lambda expression to return the length of the string.

# %%
word = "Python"
str_length = lambda w: len(w)
print(str_length(word))

# %% [markdown]
# **Question 17**```pythonword = "Azure"```Write a lambda expression to return the first character of the string.

# %%
word = "Azure"
first_char = lambda w: w[0]
print(first_char(word))

# %% [markdown]
# **Question 18**```pythonword = "Databricks"```Write a lambda expression to return the last character of the string.

# %%
word = "Databricks"
last_char = lambda w: w[-1]
print(last_char(word))

# %% [markdown]
# **Question 19**```pythonnumber = -45```Write a lambda expression to return the absolute value of the number without using `abs()`.

# %%
number = -45
absolute_value = lambda n: n if n >= 0 else -n
print(absolute_value(number))

# %% [markdown]
# **Question 20**```pythonmarks = 72```Write a lambda expression that returns:- "Distinction" when marks are 75 or above- "Pass" when marks are 40 to 74- "Fail" when marks are below 40

# %%
marks = 72
grade = lambda m: "Distinction" if m >= 75 else ("Pass" if m >= 40 else "Fail")
print(grade(marks))

# %% [markdown]
# # Section 2: map()

# %% [markdown]
# **Question 1**```pythonnumbers = [1, 2, 3, 4, 5, 6]```Using `map()` and a lambda expression, calculate the square of every number.

# %%
numbers = [1, 2, 3, 4, 5, 6]
result = list(map(lambda x: x ** 2, numbers))
print(result)

# %% [markdown]
# **Question 2**```pythonnumbers = [2, 3, 4, 5, 6]```Using `map()` and a lambda expression, calculate the cube of every number.

# %%
numbers = [2, 3, 4, 5, 6]
result = list(map(lambda x: x ** 3, numbers))
print(result)

# %% [markdown]
# **Question 3**```pythonnumbers = [10, 20, 30, 40, 50]```Using `map()`, add 5 to every number.

# %%
numbers = [10, 20, 30, 40, 50]
result = list(map(lambda x: x + 5, numbers))
print(result)

# %% [markdown]
# **Question 4**```pythonnumbers = [15, 25, 35, 45, 55]```Using `map()`, subtract 10 from every number.

# %%
numbers = [15, 25, 35, 45, 55]
result = list(map(lambda x: x - 10, numbers))
print(result)

# %% [markdown]
# **Question 5**```pythonnumbers = [1, 5, 10, 15, 20]```Using `map()`, multiply every number by 100.

# %%
numbers = [1, 5, 10, 15, 20]
result = list(map(lambda x: x * 100, numbers))
print(result)

# %% [markdown]
# **Question 6**```pythonnames = ["ravi", "anil", "meena", "kiran", "sneha"]```Using `map()`, convert every name to uppercase.

# %%
names = ["ravi", "anil", "meena", "kiran", "sneha"]
result = list(map(lambda x: x.upper(), names))
print(result)

# %% [markdown]
# **Question 7**```pythonnames = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]```Using `map()`, convert every name to lowercase.

# %%
names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]
result = list(map(lambda x: x.lower(), names))
print(result)

# %% [markdown]
# **Question 8**```pythonnames = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]```Using `map()`, convert every name to title case.

# %%
names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]
result = list(map(lambda x: x.title(), names))
print(result)

# %% [markdown]
# **Question 9**```pythonwords = ["Python", "Azure", "Databricks", "Cloud", "AI"]```Using `map()`, calculate the length of every word.

# %%
words = ["Python", "Azure", "Databricks", "Cloud", "AI"]
result = list(map(lambda x: len(x), words))
print(result)

# %% [markdown]
# **Question 10**```pythonwords = ["Python", "Azure", "Docker", "Linux", "Spark"]```Using `map()`, extract the first character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
result = list(map(lambda x: x[0], words))
print(result)

# %% [markdown]
# **Question 11**```pythonwords = ["Python", "Azure", "Docker", "Linux", "Spark"]```Using `map()`, extract the last character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
result = list(map(lambda x: x[-1], words))
print(result)

# %% [markdown]
# **Question 12**```pythontemperatures = [0, 10, 20, 30, 40]```Using `map()`, convert every Celsius temperature into Fahrenheit.

# %%
temperatures = [0, 10, 20, 30, 40]
result = list(map(lambda c: (c * 9 / 5) + 32, temperatures))
print(result)

# %% [markdown]
# **Question 13**```pythonprices = [100, 250, 500, 1000, 2500]```Using `map()`, calculate 18% GST for every price.

# %%
prices = [100, 250, 500, 1000, 2500]
result = list(map(lambda p: p * 0.18, prices))
print(result)

# %% [markdown]
# **Question 14**```pythonprices = [100, 250, 500, 1000, 2500]```Using `map()`, calculate the final price after adding 18% GST.

# %%
prices = [100, 250, 500, 1000, 2500]
result = list(map(lambda p: p + (p * 0.18), prices))
print(result)

# %% [markdown]
# **Question 15**```pythondecimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999]```Using `map()`, round every number to two decimal places.

# %%
decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999]
result = list(map(lambda x: round(x, 2), decimal_numbers))
print(result)

# %% [markdown]
# **Question 16**```pythonvalues = [-10, 20, -35, 40, -55, 60]```Using `map()`, convert every number into its absolute value.

# %%
values = [-10, 20, -35, 40, -55, 60]
result = list(map(lambda x: x if x >= 0 else -x, values))
print(result)

# %% [markdown]
# **Question 17**```pythonnumbers = [10, 20, 30, 40, 50]```Using `map()`, convert every integer into a string.

# %%
numbers = [10, 20, 30, 40, 50]
result = list(map(lambda x: str(x), numbers))
print(result)

# %% [markdown]
# **Question 18**```pythonnames = ["  Ravi  ", " Anil", "Meena ", "  Kiran "]```Using `map()`, remove leading and trailing spaces from every name.

# %%
names = ["  Ravi  ", " Anil", "Meena ", "  Kiran "]
result = list(map(lambda x: x.strip(), names))
print(result)

# %% [markdown]
# **Question 19**```pythonemployees = [    {"id": 101, "name": "Rahul", "salary": 45000},    {"id": 102, "name": "Anil", "salary": 65000},    {"id": 103, "name": "Sneha", "salary": 72000},    {"id": 104, "name": "Kiran", "salary": 82000}]```Using `map()`, extract only employee names.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
result = list(map(lambda e: e["name"], employees))
print(result)

# %% [markdown]
# **Question 20**```pythonemployees = [    {"id": 101, "name": "Rahul", "salary": 45000},    {"id": 102, "name": "Anil", "salary": 65000},    {"id": 103, "name": "Sneha", "salary": 72000},    {"id": 104, "name": "Kiran", "salary": 82000}]```Using `map()`, create a new list of dictionaries containing:- Employee name- Original salary- Salary after a 10% increment*Do not modify the original list.*

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
result = list(map(lambda e: {"name": e["name"], "original_salary": e["salary"], "new_salary": e["salary"] * 1.1}, employees))
print(result)

# %% [markdown]
# # Section 3: filter()

# %% [markdown]
# **Question 1**```pythonnumbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]```Using `filter()`, extract all even numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = list(filter(lambda x: x % 2 == 0, numbers))
print(result)

# %% [markdown]
# **Question 2**```pythonnumbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]```Using `filter()`, extract all odd numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = list(filter(lambda x: x % 2 != 0, numbers))
print(result)

# %% [markdown]
# **Question 3**```pythonnumbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]```Using `filter()`, extract all numbers greater than 50.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = list(filter(lambda x: x > 50, numbers))
print(result)

# %% [markdown]
# **Question 4**```pythonnumbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100]```Using `filter()`, extract all numbers less than 100.

# %%
numbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100]
result = list(filter(lambda x: x < 100, numbers))
print(result)

# %% [markdown]
# **Question 5**```pythonnumbers = [-15, -8, 0, 4, 12, -25, 37, 42]```Using `filter()`, extract all positive numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
result = list(filter(lambda x: x > 0, numbers))
print(result)

# %% [markdown]
# **Question 6**```pythonnumbers = [-15, -8, 0, 4, 12, -25, 37, 42]```Using `filter()`, extract all negative numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
result = list(filter(lambda x: x < 0, numbers))
print(result)

# %% [markdown]
# **Question 7**```pythonnumbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]```Using `filter()`, remove all zero values.

# %%
numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]
result = list(filter(lambda x: x != 0, numbers))
print(result)

# %% [markdown]
# **Question 8**```pythonwords = ["python", "azure", "ai", "developer", "cloud", "analytics"]```Using `filter()`, extract words containing more than five characters.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics"]
result = list(filter(lambda w: len(w) > 5, words))
print(result)

# %% [markdown]
# **Question 9**```pythonnames = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]```Using `filter()`, extract names beginning with "A".

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
result = list(filter(lambda n: n.startswith("A"), names))
print(result)

# %% [markdown]
# **Question 10**```pythonnames = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]```Using `filter()`, extract names ending with "n".

# %%
names = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]
result = list(filter(lambda n: n.endswith("n"), names))
print(result)

# %% [markdown]
# **Question 11**```pythonnumbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]```Using `filter()`, extract all multiples of 5.

# %%
numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]
result = list(filter(lambda x: x % 5 == 0, numbers))
print(result)

# %% [markdown]
# **Question 12**```pythonnumbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]```Using `filter()`, extract numbers divisible by both 3 and 5.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
result = list(filter(lambda x: x % 3 == 0 and x % 5 == 0, numbers))
print(result)

# %% [markdown]
# **Question 13**```pythonwords = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]```Using `filter()`, extract all palindrome words.

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
result = list(filter(lambda w: w == w[::-1], words))
print(result)

# %% [markdown]
# **Question 14**```pythonemails = [    "john@gmail.com",    "rahul@yahoo.com",    "admin@python.com",    "support@azure.org",    "sales@company.com"]```Using `filter()`, extract email addresses ending with ".com".

# %%
emails = [
    "john@gmail.com",
    "rahul@yahoo.com",
    "admin@python.com",
    "support@azure.org",
    "sales@company.com"
]
result = list(filter(lambda e: e.endswith(".com"), emails))
print(result)

# %% [markdown]
# **Question 15**```pythonfiles = [    "sales.csv",    "employees.xlsx",    "products.csv",    "report.pdf",    "customers.csv",    "notes.txt"]```Using `filter()`, extract all CSV files.

# %%
files = [
    "sales.csv",
    "employees.xlsx",
    "products.csv",
    "report.pdf",
    "customers.csv",
    "notes.txt"
]
result = list(filter(lambda f: f.endswith(".csv"), files))
print(result)

# %% [markdown]
# **Question 16**```pythonemployees = [    {"name": "Rahul", "salary": 45000},    {"name": "Anil", "salary": 65000},    {"name": "Sneha", "salary": 72000},    {"name": "Kiran", "salary": 82000},    {"name": "Meena", "salary": 55000}]```Using `filter()`, extract employees whose salary is greater than 60000.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
result = list(filter(lambda e: e["salary"] > 60000, employees))
print(result)

# %% [markdown]
# **Question 17**```pythonstudents = [    {"name": "Ravi", "marks": 92},    {"name": "Kiran", "marks": 68},    {"name": "Meena", "marks": 85},    {"name": "Ajay", "marks": 48},    {"name": "Sneha", "marks": 79}]```Using `filter()`, extract students who scored more than 80.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79}
]
result = list(filter(lambda s: s["marks"] > 80, students))
print(result)

# %% [markdown]
# **Question 18**```pythonproducts = [    {"name": "Laptop", "price": 55000, "stock": 5},    {"name": "Mouse", "price": 600, "stock": 25},    {"name": "Keyboard", "price": 1500, "stock": 0},    {"name": "Monitor", "price": 18000, "stock": 8},    {"name": "Printer", "price": 12000, "stock": 0}]```Using `filter()`, extract products that are currently in stock.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0}
]
result = list(filter(lambda p: p["stock"] > 0, products))
print(result)

# %% [markdown]
# **Question 19**```pythonpeople = [    {"name": "Rahul", "age": 17},    {"name": "Anil", "age": 25},    {"name": "Sneha", "age": 16},    {"name": "Kiran", "age": 32},    {"name": "Meena", "age": 18}]```Using `filter()`, extract people who are eligible to vote.

# %%
people = [
    {"name": "Rahul", "age": 17},
    {"name": "Anil", "age": 25},
    {"name": "Sneha", "age": 16},
    {"name": "Kiran", "age": 32},
    {"name": "Meena", "age": 18}
]
result = list(filter(lambda p: p["age"] >= 18, people))
print(result)

# %% [markdown]
# **Question 20**```pythonemployees = [    {"name": "Rahul", "department": "IT", "active": True},    {"name": "Anil", "department": "HR", "active": True},    {"name": "Sneha", "department": "IT", "active": False},    {"name": "Kiran", "department": "IT", "active": True},    {"name": "Meena", "department": "Sales", "active": True}]```Using `filter()`, extract employees who belong to the IT department and are active.

# %%
employees = [
    {"name": "Rahul", "department": "IT", "active": True},
    {"name": "Anil", "department": "HR", "active": True},
    {"name": "Sneha", "department": "IT", "active": False},
    {"name": "Kiran", "department": "IT", "active": True},
    {"name": "Meena", "department": "Sales", "active": True}
]
result = list(filter(lambda e: e["department"] == "IT" and e["active"], employees))
print(result)

# %% [markdown]
# # Section 4: reduce()

# %%
from functools import reduce

# %% [markdown]
# **Question 1**```pythonnumbers = [10, 20, 30, 40, 50]```Using `reduce()`, calculate the sum of all numbers.

# %%
numbers = [10, 20, 30, 40, 50]
result = reduce(lambda a, b: a + b, numbers)
print(result)

# %% [markdown]
# **Question 2**```pythonnumbers = [2, 3, 4, 5]```Using `reduce()`, calculate the product of all numbers.

# %%
numbers = [2, 3, 4, 5]
result = reduce(lambda a, b: a * b, numbers)
print(result)

# %% [markdown]
# **Question 3**```pythonnumbers = [45, 12, 89, 34, 67, 91, 28]```Using `reduce()`, find the maximum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]
result = reduce(lambda a, b: a if a > b else b, numbers)
print(result)

# %% [markdown]
# **Question 4**```pythonnumbers = [45, 12, 89, 34, 67, 91, 28]```Using `reduce()`, find the minimum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]
result = reduce(lambda a, b: a if a < b else b, numbers)
print(result)

# %% [markdown]
# **Question 5**```pythonwords = ["Python", " ", "is", " ", "powerful"]```Using `reduce()`, combine all strings into one sentence.

# %%
words = ["Python", " ", "is", " ", "powerful"]
result = reduce(lambda a, b: a + b, words)
print(result)

# %% [markdown]
# **Question 6**```pythonwords = ["Python", "Azure", "Cloud", "AI"]```Using `reduce()`, calculate the total number of characters in all words.

# %%
words = ["Python", "Azure", "Cloud", "AI"]
result = reduce(lambda acc, w: acc + len(w), words, 0)
print(result)

# %% [markdown]
# **Question 7**```pythonnumber = 6numbers = list(range(1, number + 1))```Using `reduce()`, calculate the factorial of `number`.

# %%
number = 6
numbers = list(range(1, number + 1))
result = reduce(lambda a, b: a * b, numbers)
print(result)

# %% [markdown]
# **Question 8**```pythonnumbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]```Using `reduce()`, calculate the sum of only the even numbers. *Do not create a separate filtered list.*

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = reduce(lambda acc, x: acc + x if x % 2 == 0 else acc, numbers, 0)
print(result)

# %% [markdown]
# **Question 9**```pythonnumbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]```Using `reduce()`, calculate the sum of only the odd numbers. *Do not create a separate filtered list.*

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = reduce(lambda acc, x: acc + x if x % 2 != 0 else acc, numbers, 0)
print(result)

# %% [markdown]
# **Question 10**```pythonwords = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]```Using `reduce()`, find the longest word.

# %%
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
result = reduce(lambda a, b: a if len(a) >= len(b) else b, words)
print(result)

# %% [markdown]
# **Question 11**```pythonwords = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]```Using `reduce()`, find the shortest word.

# %%
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
result = reduce(lambda a, b: a if len(a) <= len(b) else b, words)
print(result)

# %% [markdown]
# **Question 12**```pythonsalaries = [45000, 65000, 72000, 82000, 55000]```Using `reduce()`, calculate the total salary.

# %%
salaries = [45000, 65000, 72000, 82000, 55000]
result = reduce(lambda a, b: a + b, salaries)
print(result)

# %% [markdown]
# **Question 13**```pythonemployees = [    {"name": "Rahul", "salary": 45000},    {"name": "Anil", "salary": 65000},    {"name": "Sneha", "salary": 72000},    {"name": "Kiran", "salary": 82000},    {"name": "Meena", "salary": 55000}]```Using `reduce()`, calculate the total payroll directly from the dictionaries.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
result = reduce(lambda acc, e: acc + e["salary"], employees, 0)
print(result)

# %% [markdown]
# **Question 14**```pythonemployees = [    {"name": "Rahul", "salary": 45000},    {"name": "Anil", "salary": 65000},    {"name": "Sneha", "salary": 72000},    {"name": "Kiran", "salary": 82000},    {"name": "Meena", "salary": 55000}]```Using `reduce()`, find the employee with the highest salary.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
result = reduce(lambda a, b: a if a["salary"] > b["salary"] else b, employees)
print(result)

# %% [markdown]
# **Question 15**```pythonstudents = [    {"name": "Ravi", "marks": 92},    {"name": "Kiran", "marks": 68},    {"name": "Meena", "marks": 85},    {"name": "Ajay", "marks": 48},    {"name": "Rahul", "marks": 95}]```Using `reduce()`, find the student with the highest marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Rahul", "marks": 95}
]
result = reduce(lambda a, b: a if a["marks"] > b["marks"] else b, students)
print(result)

# %% [markdown]
# **Question 16**```pythonproducts = [    {"name": "Laptop", "price": 55000, "stock": 5},    {"name": "Mouse", "price": 600, "stock": 25},    {"name": "Keyboard", "price": 1500, "stock": 15},    {"name": "Monitor", "price": 18000, "stock": 8}]```Using `reduce()`, calculate the total stock quantity.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
result = reduce(lambda acc, p: acc + p["stock"], products, 0)
print(result)

# %% [markdown]
# **Question 17**```pythonproducts = [    {"name": "Laptop", "price": 55000, "stock": 5},    {"name": "Mouse", "price": 600, "stock": 25},    {"name": "Keyboard", "price": 1500, "stock": 15},    {"name": "Monitor", "price": 18000, "stock": 8}]```Using `reduce()`, calculate the total inventory value using `price × stock`.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
result = reduce(lambda acc, p: acc + (p["price"] * p["stock"]), products, 0)
print(result)

# %% [markdown]
# **Question 18**```pythonsales = [12000, 25000, 18000, 45000, 30000, 52000]```Using `reduce()`, calculate the total sales amount.

# %%
sales = [12000, 25000, 18000, 45000, 30000, 52000]
result = reduce(lambda a, b: a + b, sales)
print(result)

# %% [markdown]
# **Question 19**```pythondictionaries = [    {"name": "Rahul"},    {"age": 30},    {"department": "IT"},    {"salary": 65000}]```Using `reduce()`, merge all dictionaries into one dictionary.

# %%
dictionaries = [
    {"name": "Rahul"},
    {"age": 30},
    {"department": "IT"},
    {"salary": 65000}
]
result = reduce(lambda a, b: {**a, **b}, dictionaries, {})
print(result)

# %% [markdown]
# **Question 20**```pythonnumbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]```Using `reduce()`, calculate the sum of unique numbers only. *Do not directly use sum(set(numbers)).*

# %%
numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]
result = reduce(lambda acc, x: (acc[0] + x, acc[1] | {x}) if x not in acc[1] else acc, numbers, (0, set()))[0]
print(result)

# %% [markdown]
# # Section 5: Combined Lambda, map(), filter(), and reduce()

# %% [markdown]
# **Question 1**```pythonnumbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]```Using `filter()` and `map()`:1. Extract all even numbers.2. Calculate the square of every even number.3. Return the squared values as a list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = list(map(lambda x: x ** 2, filter(lambda x: x % 2 == 0, numbers)))
print(result)

# %% [markdown]
# **Question 2**```pythonnumbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]```Using `filter()` and `reduce()`:1. Extract all odd numbers.2. Calculate their total sum.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = reduce(lambda a, b: a + b, filter(lambda x: x % 2 != 0, numbers))
print(result)

# %% [markdown]
# **Question 3**```pythonnumbers = [10, 25, 40, 55, 70, 85, 100]```Using `filter()` and `map()`:1. Extract numbers greater than 50.2. Multiply every selected number by 2.

# %%
numbers = [10, 25, 40, 55, 70, 85, 100]
result = list(map(lambda x: x * 2, filter(lambda x: x > 50, numbers)))
print(result)

# %% [markdown]
# **Question 4**```pythonnumbers = [-15, 20, -35, 40, 50, -10, 60]```Using `filter()`, `map()`, and `reduce()`:1. Extract positive numbers.2. Calculate the square of every positive number.3. Calculate the total sum of the squared values.

# %%
numbers = [-15, 20, -35, 40, 50, -10, 60]
result = reduce(lambda a, b: a + b, map(lambda x: x ** 2, filter(lambda x: x > 0, numbers)))
print(result)

# %% [markdown]
# **Question 5**```pythonwords = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]```Using `filter()` and `map()`:1. Extract words containing more than five characters.2. Convert the selected words to uppercase.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]
result = list(map(lambda w: w.upper(), filter(lambda w: len(w) > 5, words)))
print(result)

# %% [markdown]
# **Question 6**```pythonnames = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]```Using `filter()` and `map()`:1. Extract names beginning with "A".2. Convert the selected names to lowercase.

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
result = list(map(lambda n: n.lower(), filter(lambda n: n.startswith("A"), names)))
print(result)

# %% [markdown]
# **Question 7**```pythonnumbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]```Using `filter()` and `reduce()`:1. Extract numbers divisible by both 3 and 5.2. Calculate their total sum.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
result = reduce(lambda a, b: a + b, filter(lambda x: x % 3 == 0 and x % 5 == 0, numbers))
print(result)

# %% [markdown]
# **Question 8**```pythonwords = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]```Using `filter()` and `reduce()`:1. Extract palindrome words.2. Join them into one string separated by " | ".

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
result = reduce(lambda a, b: a + " | " + b, filter(lambda w: w == w[::-1], words))
print(result)

# %% [markdown]
# **Question 9**```pythontemperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]```Using `filter()`, `map()`, and `reduce()`:1. Extract temperatures greater than 30°C.2. Convert the selected values into Fahrenheit.3. Calculate the average Fahrenheit temperature.

# %%
temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]
selected = list(filter(lambda t: t > 30, temperatures))
fahrenheit = list(map(lambda c: (c * 9 / 5) + 32, selected))
result = reduce(lambda a, b: a + b, fahrenheit) / len(fahrenheit)
print(result)

# %% [markdown]
# **Question 10**```pythonprices = [450, 1200, 2500, 800, 5000, 1500, 7500]```Using `filter()`, `map()`, and `reduce()`:1. Extract prices greater than 1000.2. Apply a 10% discount to every selected price.3. Calculate the total discounted amount.

# %%
prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
selected = list(filter(lambda p: p > 1000, prices))
discounted = list(map(lambda p: p * 0.9, selected))
result = reduce(lambda a, b: a + b, discounted)
print(result)

# %% [markdown]
# **Question 11**```pythonemployees = [    {"id": 101, "name": "Rahul", "salary": 45000},    {"id": 102, "name": "Anil", "salary": 65000},    {"id": 103, "name": "Sneha", "salary": 72000},    {"id": 104, "name": "Kiran", "salary": 82000},    {"id": 105, "name": "Meena", "salary": 55000}]```Using `filter()` and `map()`:1. Extract employees earning more than 60000.2. Increase their salary by 10%.3. Return their names and updated salaries.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000},
    {"id": 105, "name": "Meena", "salary": 55000}
]
selected = filter(lambda e: e["salary"] > 60000, employees)
result = list(map(lambda e: {"name": e["name"], "new_salary": e["salary"] * 1.1}, selected))
print(result)

# %% [markdown]
# **Question 12**```pythonemployees = [    {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},    {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},    {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},    {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},    {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}]```Using `filter()` and `reduce()`:1. Extract employees from the IT department.2. Calculate the total salary of IT employees.

# %%
employees = [
    {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},
    {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},
    {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},
    {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},
    {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}
]
it_employees = filter(lambda e: e["department"] == "IT", employees)
result = reduce(lambda acc, e: acc + e["salary"], it_employees, 0)
print(result)

# %% [markdown]
# **Question 13**```pythonemployees = [    {"id": 101, "name": "Rahul", "salary": 45000, "active": True},    {"id": 102, "name": "Anil", "salary": 65000, "active": True},    {"id": 103, "name": "Sneha", "salary": 72000, "active": False},    {"id": 104, "name": "Kiran", "salary": 82000, "active": True},    {"id": 105, "name": "Meena", "salary": 55000, "active": True},    {"id": 106, "name": "Arjun", "salary": 98000, "active": False}]```Using `filter()`, `map()`, and `reduce()`:1. Extract active employees.2. Increase every active employee's salary by 15%.3. Calculate the total updated payroll.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000, "active": True},
    {"id": 102, "name": "Anil", "salary": 65000, "active": True},
    {"id": 103, "name": "Sneha", "salary": 72000, "active": False},
    {"id": 104, "name": "Kiran", "salary": 82000, "active": True},
    {"id": 105, "name": "Meena", "salary": 55000, "active": True},
    {"id": 106, "name": "Arjun", "salary": 98000, "active": False}
]
active = filter(lambda e: e["active"], employees)
updated = map(lambda e: e["salary"] * 1.15, active)
result = reduce(lambda a, b: a + b, updated)
print(result)

# %% [markdown]
# **Question 14**```pythonstudents = [    {"name": "Ravi", "marks": 92, "passed": True},    {"name": "Kiran", "marks": 68, "passed": True},    {"name": "Meena", "marks": 85, "passed": True},    {"name": "Ajay", "marks": 48, "passed": True},    {"name": "Sneha", "marks": 35, "passed": False},    {"name": "Rahul", "marks": 95, "passed": True}]```Using `filter()` and `reduce()`:1. Extract students who passed.2. Find the topper among the passed students.

# %%
students = [
    {"name": "Ravi", "marks": 92, "passed": True},
    {"name": "Kiran", "marks": 68, "passed": True},
    {"name": "Meena", "marks": 85, "passed": True},
    {"name": "Ajay", "marks": 48, "passed": True},
    {"name": "Sneha", "marks": 35, "passed": False},
    {"name": "Rahul", "marks": 95, "passed": True}
]
passed = filter(lambda s: s["passed"], students)
result = reduce(lambda a, b: a if a["marks"] > b["marks"] else b, passed)
print(result)

# %% [markdown]
# **Question 15**```pythonstudents = [    {"name": "Ravi", "marks": 92},    {"name": "Kiran", "marks": 68},    {"name": "Meena", "marks": 85},    {"name": "Ajay", "marks": 48},    {"name": "Sneha", "marks": 79},    {"name": "Rahul", "marks": 95}]```Using `filter()`, `map()`, and `reduce()`:1. Extract students scoring more than 70.2. Extract only their marks.3. Calculate the average marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79},
    {"name": "Rahul", "marks": 95}
]
selected = filter(lambda s: s["marks"] > 70, students)
marks = list(map(lambda s: s["marks"], selected))
result = reduce(lambda a, b: a + b, marks) / len(marks)
print(result)

# %% [markdown]
# **Question 16**```pythonproducts = [    {"name": "Laptop", "price": 55000, "stock": 5},    {"name": "Mouse", "price": 600, "stock": 25},    {"name": "Keyboard", "price": 1500, "stock": 0},    {"name": "Monitor", "price": 18000, "stock": 8},    {"name": "Printer", "price": 12000, "stock": 0},    {"name": "SSD", "price": 6500, "stock": 12}]```Using `filter()`, `map()`, and `reduce()`:1. Extract products currently in stock.2. Calculate each product's inventory value using `price × stock`.3. Calculate the total inventory value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0},
    {"name": "SSD", "price": 6500, "stock": 12}
]
in_stock = filter(lambda p: p["stock"] > 0, products)
values = map(lambda p: p["price"] * p["stock"], in_stock)
result = reduce(lambda a, b: a + b, values)
print(result)

# %% [markdown]
# **Question 17**```pythonproducts = [    {"name": "Laptop", "price": 55000, "category": "Electronics"},    {"name": "Chair", "price": 4500, "category": "Furniture"},    {"name": "Monitor", "price": 18000, "category": "Electronics"},    {"name": "Desk", "price": 8500, "category": "Furniture"},    {"name": "SSD", "price": 6500, "category": "Electronics"}]```Using `filter()`, `map()`, and `reduce()`:1. Extract products belonging to the Electronics category.2. Apply a 20% discount.3. Calculate the total discounted value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "category": "Electronics"},
    {"name": "Chair", "price": 4500, "category": "Furniture"},
    {"name": "Monitor", "price": 18000, "category": "Electronics"},
    {"name": "Desk", "price": 8500, "category": "Furniture"},
    {"name": "SSD", "price": 6500, "category": "Electronics"}
]
electronics = filter(lambda p: p["category"] == "Electronics", products)
discounted = map(lambda p: p["price"] * 0.8, electronics)
result = reduce(lambda a, b: a + b, discounted)
print(result)

# %% [markdown]
# **Question 18**```pythonorders = [    {"order_id": 1001, "amount": 1200, "status": "Delivered"},    {"order_id": 1002, "amount": 3500, "status": "Pending"},    {"order_id": 1003, "amount": 8500, "status": "Delivered"},    {"order_id": 1004, "amount": 4200, "status": "Cancelled"},    {"order_id": 1005, "amount": 7600, "status": "Delivered"},    {"order_id": 1006, "amount": 5100, "status": "Pending"}]```Using `filter()` and `reduce()`:1. Extract delivered orders.2. Calculate the total delivered revenue.

# %%
orders = [
    {"order_id": 1001, "amount": 1200, "status": "Delivered"},
    {"order_id": 1002, "amount": 3500, "status": "Pending"},
    {"order_id": 1003, "amount": 8500, "status": "Delivered"},
    {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
    {"order_id": 1005, "amount": 7600, "status": "Delivered"},
    {"order_id": 1006, "amount": 5100, "status": "Pending"}
]
delivered = filter(lambda o: o["status"] == "Delivered", orders)
result = reduce(lambda acc, o: acc + o["amount"], delivered, 0)
print(result)

# %% [markdown]
# **Question 19**```pythontransactions = [    {"id": 1, "amount": 1200},    {"id": 2, "amount": 5200},    {"id": 3, "amount": 18000},    {"id": 4, "amount": 2500},    {"id": 5, "amount": 9600},    {"id": 6, "amount": 7200}]```Using `filter()`, `map()`, and `reduce()`:1. Extract transactions whose amount is greater than 5000.2. Add 18% GST to every selected transaction.3. Calculate the grand total after GST.

# %%
transactions = [
    {"id": 1, "amount": 1200},
    {"id": 2, "amount": 5200},
    {"id": 3, "amount": 18000},
    {"id": 4, "amount": 2500},
    {"id": 5, "amount": 9600},
    {"id": 6, "amount": 7200}
]
selected = filter(lambda t: t["amount"] > 5000, transactions)
with_gst = map(lambda t: t["amount"] * 1.18, selected)
result = reduce(lambda a, b: a + b, with_gst)
print(result)

# %% [markdown]
# **Question 20**```pythonsales_records = [    {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},    {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},    {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},    {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},    {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},    {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}]```Using `filter()`, `map()`, and `reduce()`:1. Extract active salespeople from the South region.2. Calculate a 5% incentive for each selected salesperson.3. Create a list containing salesperson name, sales amount, and incentive.4. Calculate the total incentive payable.

# %%
sales_records = [
    {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},
    {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},
    {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},
    {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},
    {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},
    {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}
]
selected = filter(lambda s: s["region"] == "South" and s["active"], sales_records)
result = list(map(lambda s: {"salesperson": s["salesperson"], "sales": s["sales"], "incentive": s["sales"] * 0.05}, selected))
total_incentive = reduce(lambda acc, r: acc + r["incentive"], result, 0)
print(result)
print(total_incentive)
